# %%
import numpy as np
import pandas as pd
import sqlite3
import time

# %%
conn=sqlite3.connect('inventory.db')

# %%
table=pd.read_sql_query("select name from sqlite_master where type='table'",conn)
table
# Out:
#                      name
# 0  begin_inventory - Copy
# 1    end_inventory - Copy
# 2               purchases
# 3         purchase_prices
# 4                   sales
# 5          vendor_invoice

# %%
for tables in table['name']:
    print('-'*50,f"{tables}",'-'*50)
    count_df=pd.read_sql(f"select count(*) as count from `{tables}`",conn)
    print("count of records :",count_df['count'][0])
    display(pd.read_sql(f"select * from `{tables}` limit 5",conn))
# Out:
# -------------------------------------------------- begin_inventory - Copy --------------------------------------------------
# count of records : 206529
#          InventoryId  Store          City  Brand                  Description  \
# 0  1_HARDERSFIELD_58      1  HARDERSFIELD     58  Gekkeikan Black & Gold Sake
# 1  1_HARDERSFIELD_60      1  HARDERSFIELD     60       Canadian Club 1858 VAP
# 2  1_HARDERSFIELD_62      1  HARDERSFIELD     62     Herradura Silver Tequila
# 3  1_HARDERSFIELD_63      1  HARDERSFIELD     63   Herradura Reposado Tequila
# 4  1_HARDERSFIELD_72      1  HARDERSFIELD     72         No. 3 London Dry Gin
#
#     Size  onHand  Price   startDate
# 0  750mL       8  12.99  2024-01-01
# 1  750mL       7  10.99  2024-01-01
# 2  750mL       6  36.99  2024-01-01
# 3  750mL       3  38.99  2024-01-01
# 4  750mL       6  34.99  2024-01-01
# -------------------------------------------------- end_inventory - Copy --------------------------------------------------
# ...

# %%
count_df=pd.read_sql("select count(*) from purchases",conn)
count_df['count(*)'][0]
# Out:
# 2372474

# %%
purchase=pd.read_sql("select * from purchases where VendorNumber=4466",conn)
purchase
# Out:
#               InventoryId  Store  Brand                   Description   Size  \
# 0        30_CULCHETH_5255     30   5255  TGI Fridays Ultimte Mudslide  1.75L
# 1       34_PITMERDEN_5215     34   5215  TGI Fridays Long Island Iced  1.75L
# 2     1_HARDERSFIELD_5255      1   5255  TGI Fridays Ultimte Mudslide  1.75L
# 3       38_GOULCREST_5215     38   5215  TGI Fridays Long Island Iced  1.75L
# 4     59_CLAETHORPES_5215     59   5215  TGI Fridays Long Island Iced  1.75L
# ...                   ...    ...    ...                           ...    ...
# 2187     81_PEMBROKE_5215     81   5215  TGI Fridays Long Island Iced  1.75L
# 2188   62_KILMARNOCK_5255     62   5255  TGI Fridays Ultimte Mudslide  1.75L
# 2189    34_PITMERDEN_5215     34   5215  TGI Fridays Long Island Iced  1.75L
# 2190     6_GOULCREST_5215      6   5215  TGI Fridays Long Island Iced  1.75L
# 2191    35_HALIVAARA_5255     35   5255  TGI Fridays Ultimte Mudslide  1.75L
#
# ...

# %%
purchase_price=pd.read_sql("select * from purchase_prices where VendorNumber=4466",conn)

# %%
vendor_invoices=pd.read_sql("select * from vendor_invoice where VendorNumber=4466",conn)

# %%
sale=pd.read_sql("select * from Sales  where VendorNo=4466",conn)

# %%
purchase
# Out:
#               InventoryId  Store  Brand                   Description   Size  \
# 0        30_CULCHETH_5255     30   5255  TGI Fridays Ultimte Mudslide  1.75L
# 1       34_PITMERDEN_5215     34   5215  TGI Fridays Long Island Iced  1.75L
# 2     1_HARDERSFIELD_5255      1   5255  TGI Fridays Ultimte Mudslide  1.75L
# 3       38_GOULCREST_5215     38   5215  TGI Fridays Long Island Iced  1.75L
# 4     59_CLAETHORPES_5215     59   5215  TGI Fridays Long Island Iced  1.75L
# ...                   ...    ...    ...                           ...    ...
# 2187     81_PEMBROKE_5215     81   5215  TGI Fridays Long Island Iced  1.75L
# 2188   62_KILMARNOCK_5255     62   5255  TGI Fridays Ultimte Mudslide  1.75L
# 2189    34_PITMERDEN_5215     34   5215  TGI Fridays Long Island Iced  1.75L
# 2190     6_GOULCREST_5215      6   5215  TGI Fridays Long Island Iced  1.75L
# 2191    35_HALIVAARA_5255     35   5255  TGI Fridays Ultimte Mudslide  1.75L
#
# ...

# %%
purchase.groupby(['Brand','PurchasePrice'])[['Quantity','Dollars']].sum()
# Out:
#                      Quantity   Dollars
# Brand PurchasePrice
# 3140  11.19              4640  51921.60
# 5215  9.41               4923  46325.43
# 5255  9.35               6215  58110.25

# %%
purchase_price
# Out:
#    Brand                   Description  Price    Size Volume  Classification  \
# 0   5215  TGI Fridays Long Island Iced  12.99  1750mL   1750               1
# 1   5255  TGI Fridays Ultimte Mudslide  12.99  1750mL   1750               1
# 2   3140      TGI Fridays Orange Dream  14.99  1750mL   1750               1
#
#    PurchasePrice  VendorNumber                   VendorName
# 0           9.41          4466  AMERICAN VINTAGE BEVERAGE
# 1           9.35          4466  AMERICAN VINTAGE BEVERAGE
# 2          11.19          4466  AMERICAN VINTAGE BEVERAGE

# %%
vendor_invoices['PONumber'].nunique()
# Out:
# 55

# %%
vendor_invoices.columns
# Out:
# Index(['VendorNumber', 'VendorName', 'InvoiceDate', 'PONumber', 'PODate',
#        'PayDate', 'Quantity', 'Dollars', 'Freight', 'Approval'],
#       dtype='object')

# %%
sale.groupby('Brand')[['SalesQuantity','SalesDollars','SalesPrice']].sum()
# Out:
#        SalesQuantity  SalesDollars  SalesPrice
# Brand
# 3140            3890      50531.10    30071.85
# 5215            4651      60416.49    41542.02
# 5255            6096      79187.04    51180.60

# %%
vendor_invoices.columns
# Out:
# Index(['VendorNumber', 'VendorName', 'InvoiceDate', 'PONumber', 'PODate',
#        'PayDate', 'Quantity', 'Dollars', 'Freight', 'Approval'],
#       dtype='object')

# %%
freight_summary=pd.read_sql_query("""select VendorNumber ,sum(Freight) as FreightCost from vendor_invoice
                                  group by VendorNumber""",conn)

# %%
freight_summary
# Out:
#      VendorNumber  FreightCost
# 0               2        27.08
# 1              54         0.48
# 2              60       367.52
# 3             105        62.39
# 4             200         6.19
# ..            ...          ...
# 121         98450       856.02
# 122         99166       130.09
# 123        172662       178.34
# 124        173357       202.50
# 125        201359         0.09
#
# [126 rows x 2 columns]

# %%
purchase.columns
# Out:
# Index(['InventoryId', 'Store', 'Brand', 'Description', 'Size', 'VendorNumber',
#        'VendorName', 'PONumber', 'PODate', 'ReceivingDate', 'InvoiceDate',
#        'PayDate', 'PurchasePrice', 'Quantity', 'Dollars', 'Classification'],
#       dtype='object')

# %%
purchase_price.columns
# Out:
# Index(['Brand', 'Description', 'Price', 'Size', 'Volume', 'Classification',
#        'PurchasePrice', 'VendorNumber', 'VendorName'],
#       dtype='object')

# %%
purchase_summary=pd.read_sql_query("""
select p.VendorNumber,
p.VendorName,
p.Brand,
p.PurchasePrice,
pp.Volume,
pp.Price as Actual_price,
sum(p.Quantity) as TotalPurchaseQuantity,
sum(p.Dollars) as TotalPurchaseDollar
from purchases p
join
purchase_prices pp
on p.Brand=pp.Brand
where p.PurchasePrice>0
group by p.VendorNumber,
p.VendorName,
p.Brand

order by 
TotalPurchaseQuantity
""",conn)

# %%
sale.columns
# Out:
# Index(['InventoryId', 'Store', 'Brand', 'Description', 'Size', 'SalesQuantity',
#        'SalesDollars', 'SalesPrice', 'SalesDate', 'Volume', 'Classification',
#        'ExciseTax', 'VendorNo', 'VendorName'],
#       dtype='object')

# %%
sales_summary=pd.read_sql_query("""select VendorNo,Brand,
sum(SalesDollars) as TotalSalesDollar,
sum(SalesPrice) as TotalsalesPrice,
sum(SalesQuantity) as TotalSalesQuantity,
sum(ExciseTax) as TotalExciseTax
from sales
group by VendorNo,Brand
order by TotalSalesDollar""",conn)

# %% [raw]
# # start=time.time()
# # final_table=pd.read_sql_query("""select pp.VendorNumber,
# # pp.Brand,
# # pp.Price as ActualPprice,
# # pp.PurchasePrice,
# # sum(s.SalesQuantity) as TotalSalesQuantity,
# # sum(s.SalesDollars) as TotalSalesDollar,
# # sum(s.SalesPrice) as TotalsalesPrice,
# # sum(s.ExciseTax) as TotalExciseTax,
# # sum(vi.Quantity) as TotalPurchaseQuantity,
# # sum(vi.Dollars) as TotalPurchaseDollar,
# # sum(vi.Freight) as TotalFreightCost
# # from
# # purchase_prices pp
# # join
# # sales s
# # on pp.VendorNumber=s.VendorNo
# # and pp.Brand=s.Brand
# # join
# # vendor_invoice vi
# # on pp.VendorNumber=vi.VendorNumber
# # group by
# # pp.VendorNumber,
# # pp.Brand,
# # ActualPprice,
# # pp.PurchasePrice
# # """,conn)
# # end=time.time()
# this query was taking to much time so this is not much optimissed so we have to take other optimised way for crating final_table

# %%
start=time.time()
vendor_sales_summary=pd.read_sql_query("""
with freight_summary as (
select VendorNumber ,sum(Freight) as FreightCost from vendor_invoice
group by VendorNumber
) ,purchase_summary as (
select p.VendorNumber,
p.VendorName,
p.Brand,
p.Description,
p.PurchasePrice,
pp.Volume,
pp.Price as Actual_price,
sum(p.Quantity) as TotalPurchaseQuantity,
sum(p.Dollars) as TotalPurchaseDollar
from purchases p
join
purchase_prices pp
on p.Brand=pp.Brand
where p.PurchasePrice>0
group by p.VendorNumber,
p.VendorName,
p.Brand

order by 
TotalPurchaseQuantity
),
sales_summary as(
select VendorNo,Brand,
sum(SalesDollars) as TotalSalesDollar,
sum(SalesPrice) as TotalsalesPrice,
sum(SalesQuantity) as TotalSalesQuantity,
sum(ExciseTax) as TotalExciseTax
from sales
group by VendorNo,Brand
order by TotalSalesDollar
)
select ps.VendorNumber,
ps.VendorName,
ps.Brand,
ps.Description,
ps.PurchasePrice,
ps.Actual_price,
ps.Volume,
ps.TotalPurchaseQuantity,
ps.TotalPurchaseDollar,
ss.TotalSalesDollar,
ss.TotalsalesPrice,
ss.TotalSalesQuantity,
ss.TotalExciseTax,
fs.FreightCost
from purchase_summary ps
left join
sales_summary ss
on ps.VendorNumber=ss.VendorNo
and ps.Brand=ss.Brand
left join freight_summary fs
on ps.VendorNumber=fs.VendorNumber
order by ps.TotalPurchaseDollar
""",conn)
end=time.time()
final_time=end-start

# %%
final_time
# Out:
# 63.93502616882324

# %%
vendor_sales_summary
# Out:
#        VendorNumber                   VendorName  Brand  \
# 0              7245  PROXIMO SPIRITS INC.          3065
# 1              3960  DIAGEO NORTH AMERICA INC      6127
# 2              3924  HEAVEN HILL DISTILLERIES      9123
# 3              8004  SAZERAC CO INC                5683
# 4              9815  WINE GROUP INC                8527
# ...             ...                          ...    ...
# 10687          3960  DIAGEO NORTH AMERICA INC      3545
# 10688          3960  DIAGEO NORTH AMERICA INC      4261
# 10689         17035  PERNOD RICARD USA             8068
# 10690          4425        MARTIGNETTI COMPANIES   3405
# 10691          1128  BROWN-FORMAN CORP             1233
#
#                        Description  PurchasePrice  Actual_price Volume  \
# 0         Three Olives Grape Vodka           0.71          0.99     50
# 1      The Club Strawbry Margarita           1.47          1.99    200
# 2                  Deep Eddy Vodka           0.74          0.99     50
# ...

# %%
vendor_sales_summary.dtypes
# Out:
# VendorNumber               int64
# VendorName                object
# Brand                      int64
# Description               object
# PurchasePrice            float64
# Actual_price             float64
# Volume                    object
# TotalPurchaseQuantity      int64
# TotalPurchaseDollar      float64
# TotalSalesDollar         float64
# TotalsalesPrice          float64
# TotalSalesQuantity       float64
# TotalExciseTax           float64
# FreightCost              float64
# dtype: object

# %%
vendor_sales_summary.isnull().sum()
# Out:
# VendorNumber               0
# VendorName                 0
# Brand                      0
# Description                0
# PurchasePrice              0
# Actual_price               0
# Volume                     0
# TotalPurchaseQuantity      0
# TotalPurchaseDollar        0
# TotalSalesDollar         178
# TotalsalesPrice          178
# TotalSalesQuantity       178
# TotalExciseTax           178
# FreightCost                0
# dtype: int64

# %%
vendor_sales_summary['VendorName'].unique()
# Out:
# array(['PROXIMO SPIRITS INC.       ', 'DIAGEO NORTH AMERICA INC   ',
#        'HEAVEN HILL DISTILLERIES   ', 'SAZERAC CO INC             ',
#        'WINE GROUP INC             ', 'VINILANDIA USA             ',
#        'PALM BAY INTERNATIONAL INC ', 'MARTIGNETTI COMPANIES',
#        'STE MICHELLE WINE ESTATES  ', 'ULTRA BEVERAGE COMPANY LLP ',
#        'BANFI PRODUCTS CORP        ', 'MILTONS DISTRIBUTING CO    ',
#        'M S WALKER INC             ', 'JIM BEAM BRANDS COMPANY    ',
#        'PINE STATE TRADING CO      ', 'THE IMPORTED GRAPE LLC     ',
#        'SOUTHERN WINE & SPIRITS NE ', 'DIAGEO CHATEAU ESTATE WINES',
#        'LUXCO INC                  ', 'KOBRAND CORPORATION        ',
#        'BACARDI USA INC            ', 'MHW LTD                    ',
#        'STATE WINE & SPIRITS   ', 'PERFECTA WINES             ',
#        'SAZERAC NORTH AMERICA INC. ', 'Circa Wines                ',
#        'VINEYARD BRANDS INC        ', 'CRUSH WINES                ',
# ...

# %%
vendor_sales_summary['Description'].unique()
# Out:
# array(['Three Olives Grape Vodka', 'The Club Strawbry Margarita',
#        'Deep Eddy Vodka', ..., 'Capt Morgan Original Barrel',
#        'Kendall Jackson Chard Vt RSV', 'Smirnoff Traveler'], dtype=object)

# %%
vendor_sales_summary['Volume']=vendor_sales_summary['Volume'].astype('float64')

# %%
vendor_sales_summary.dtypes
# Out:
# VendorNumber               int64
# VendorName                object
# Brand                      int64
# Description               object
# PurchasePrice            float64
# Actual_price             float64
# Volume                   float64
# TotalPurchaseQuantity      int64
# TotalPurchaseDollar      float64
# TotalSalesDollar         float64
# TotalsalesPrice          float64
# TotalSalesQuantity       float64
# TotalExciseTax           float64
# FreightCost              float64
# dtype: object

# %%
vendor_sales_summary.fillna(0,inplace=True)

# %%
vendor_sales_summary['vendorName']=vendor_sales_summary['VendorName'].str.strip()

# %%
vendor_sales_summary.dtypes
del vendor_sales_summary['vendorName']

# %%
vendor_sales_summary.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10692 entries, 0 to 10691
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   VendorNumber           10692 non-null  int64
#  1   VendorName             10692 non-null  object
#  2   Brand                  10692 non-null  int64
#  3   Description            10692 non-null  object
#  4   PurchasePrice          10692 non-null  float64
#  5   Actual_price           10692 non-null  float64
#  6   Volume                 10692 non-null  float64
#  7   TotalPurchaseQuantity  10692 non-null  int64
#  8   TotalPurchaseDollar    10692 non-null  float64
#  9   TotalSalesDollar       10692 non-null  float64
#  10  TotalsalesPrice        10692 non-null  float64
#  11  TotalSalesQuantity     10692 non-null  float64
#  12  TotalExciseTax         10692 non-null  float64
#  13  FreightCost            10692 non-null  float64
# ...

# %%
vendor_sales_summary['GrossProfit']=vendor_sales_summary['TotalSalesDollar']-vendor_sales_summary['TotalPurchaseQuantity']

# %%
vendor_sales_summary['GrossProfit'].min()
# Out:
# -24812.989999999998

# %%
vendor_sales_summary['ProfitMargin']=(vendor_sales_summary['GrossProfit']/vendor_sales_summary['TotalSalesDollar'])*100

# %%
vendor_sales_summary['StockTurnover']=vendor_sales_summary['TotalSalesQuantity']-vendor_sales_summary['TotalPurchaseQuantity']

# %%
vendor_sales_summary['SalesPurchaseRatio']=vendor_sales_summary['TotalSalesDollar']/vendor_sales_summary['TotalPurchaseDollar']

# %%
cursor=conn.cursor()

# %%
cursor.execute("""
create table vendor_sales_summay(
VendorNumber INT,
VendorName VARCHAR(100),
Brand INT,
Description VARCHAR(100),
PurchasePrice DECIMAL(10,2),
Actual_price DECIMAL(10,2),
Volume DECIMAL,
TotalPurchaseQuantity INT,
TotalPurchaseDollar DECIMAL(15,2),
TotalSalesDollar DECIMAL(15,2),
TotalsalesPrice DECIMAL(15,2),
TotalSalesQuantity INT,
TotalExciseTax DECIMAL(15,3),
FreightCost DECIMAL(15,3),
GrossProfit DECIMAL(15,3),
ProfitMargin DECIMAL(15,3),
StockTurnover DECIMAL(15,3),
SalesPurchaseRatio,
PRIMARY KEY(VendorNumber,Brand)
);
""")

# %%
pd.read_sql_query("""select * from vendor_sales_summay""",conn)
# Out:
# Empty DataFrame
# Columns: [VendorNumber, VendorName, Brand, Description, PurchasePrice, Actual_price, Volume, TotalPurchaseQuantity, TotalPurchaseDollar, TotalSalesDollar, TotalsalesPrice, TotalSalesQuantity, TotalExciseTax, FreightCost, GrossProfit, ProfitMargin, StockTurnover, SalesPurchaseRatio]
# Index: []

# %%
vendor_sales_summary.to_sql('vendor_sales_summay',conn,if_exists='replace',index=False)
# Out:
# 10692
